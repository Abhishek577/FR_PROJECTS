# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
from pandas.plotting import autocorrelation_plot
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
stock=pd.read_csv(r'C:\Users\ABHISHEK\CSV\Company Stock and Investment.csv')
stock.head(7)
# Out:
#          Date  Oil Investments  Gold Investments  Comp Stock  \
# 0  31-12-2009         0.025417          0.000150    0.017354
# 1  04-01-2010         0.026830          0.001097    0.015565
# 2  05-01-2010         0.002699          0.001560    0.001729
# 3  06-01-2010         0.021688          0.006009   -0.015906
# 4  07-01-2010        -0.006256          0.000221   -0.001849
# 5  08-01-2010         0.001269         -0.013097    0.006648
# 6  11-01-2010        -0.002417          0.023297   -0.008822
#
#    Other sharesInvestments
# 0                 0.006848
# 1                -0.004609
# 2                 0.005900
# 3                -0.018116
# 4                -0.017013
# 5                 0.027077
# 6                -0.024041

# %%
stock.shape
# Out:
# (1984, 5)

# %% [markdown]
# ***`Here we are going to predict the stock and  investment of the company in 'OIL'`***

# %%
CS=stock.drop(['Oil Investments','Gold Investments','Other sharesInvestments'],axis=1)
CS.head(7)
# Out:
#          Date  Comp Stock
# 0  31-12-2009    0.017354
# 1  04-01-2010    0.015565
# 2  05-01-2010    0.001729
# 3  06-01-2010   -0.015906
# 4  07-01-2010   -0.001849
# 5  08-01-2010    0.006648
# 6  11-01-2010   -0.008822

# %%
CS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1984 entries, 0 to 1983
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1984 non-null   object
#  1   Comp Stock  1984 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 31.1+ KB

# %% [markdown]
# `converting the date column into datetime  from object type`

# %%
CS['Date']=pd.to_datetime(CS['Date'])
CS.head(12)
#it is in yyyy-mm-dd format so we have all monthly data
# Out:
#          Date  Comp Stock
# 0  2009-12-31    0.017354
# 1  2010-04-01    0.015565
# 2  2010-05-01    0.001729
# 3  2010-06-01   -0.015906
# 4  2010-07-01   -0.001849
# 5  2010-08-01    0.006648
# 6  2010-11-01   -0.008822
# 7  2010-12-01   -0.011375
# 8  2010-01-13    0.014106
# 9  2010-01-14   -0.005792
# 10 2010-01-15   -0.016712
# 11 2010-01-19    0.044238

# %% [markdown]
# `Here we can see that 2010 jan have more than 1 days while we have data of only 1 day in case of 2010-march so they must be brought back to a normal stage`

# %%
CS.tail(12)
# Out:
#            Date  Comp Stock
# 1972 2017-10-31    0.013915
# 1973 2017-01-11   -0.012719
# 1974 2017-02-11    0.007310
# 1975 2017-03-11    0.026114
# 1976 2017-06-11    0.010145
# 1977 2017-07-11    0.003214
# 1978 2017-08-11    0.008180
# 1979 2017-09-11   -0.002043
# 1980 2017-10-11   -0.006880
# 1981 2017-11-13   -0.004008
# 1982 2017-11-14   -0.015118
# 1983 2017-11-15   -0.013190

# %% [markdown]
# ` The same thing can be seen here also 2017 november have investment data for 3 days while2017 jan have investment data of only one day`

# %%
CS.set_index('Date', inplace=True)

# %%
#clubbing the data which will show the oil investment per month as at some index we have data of more than 1 days for a single month
CS=CS.resample('MS').sum()

# %%
CS.reset_index(inplace=True)
CS
# Out:
#          Date  Comp Stock
# 0  2009-12-01    0.017354
# 1  2010-01-01    0.021966
# 2  2010-02-01    0.080202
# 3  2010-03-01    0.108993
# 4  2010-04-01    0.016247
# ..        ...         ...
# 92 2017-08-01    0.065951
# 93 2017-09-01   -0.057154
# 94 2017-10-01    0.041893
# 95 2017-11-01    0.006212
# 96 2017-12-01   -0.018938
#
# [97 rows x 2 columns]

# %%
CS.describe()
# Out:
#        Comp Stock
# count   97.000000
# mean     0.020601
# std      0.060339
# min     -0.146489
# 25%     -0.018938
# 50%      0.020474
# 75%      0.061902
# max      0.161785

# %%
CS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        97 non-null     datetime64[ns]
#  1   Comp Stock  97 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.6 KB

# %% [markdown]
# `visualizing the investment column`

# %%
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
plt.figure(figsize=(15,5),dpi=120)
sns.lineplot(x='Date',y='Comp Stock',data=CS,dashes=True,markers='2',estimator=None,ci=55,err_style='band',color='deepskyblue')
plt.show()

# %%
def adf(data):
    result=adfuller(data)
    labels = ['ADF Test Statistic','p-value','Lags Used','Number of Observations']
    for i in range(len(labels)):
        print(labels[i],' = ', result[i])
    if result[1]>0.05:
        print('The',labels[1],' is higher than 0.05 and it strongly support Null hypothesis that the data is non stationary')
    else:
         print('\nThe',labels[1],' is less than 0.05 and it strongly rejects Null hypothesis and hold the alternate hypothesis which says that the data is stationary')

# %%
adf(CS['Comp Stock'])
# Out:
# ADF Test Statistic  =  -9.792480490591315
# p-value  =  6.299650878517246e-17
# Lags Used  =  0
# Number of Observations  =  96
#
# The p-value  is less than 0.05 and it strongly rejects Null hypothesis and hold the alternate hypothesis which says that the data is stationary

# %% [markdown]
# ***`So from the graph and ADF test it's clear that the p value is higher than 0.05 which lead to drooping null hypothesis`***

# %%
plt.figure(figsize=(15,5),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
autocorrelation_plot(CS['Comp Stock'],color='lime')
plt.show()

# %%
fig=plt.figure(figsize=(20,10),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(CS['Comp Stock'],lags=20,ax=ax1,color='indigo')   #to determine AR value
ax2 = fig.add_subplot(212)

fig = sm.graphics.tsa.plot_pacf(CS['Comp Stock'],lags=20,ax=ax2,color='greenyellow') # to determine MA value
plt.tight_layout
plt.show()

# %%
model=sm.tsa.statespace.SARIMAX(CS['Comp Stock'],order=(6,1,1),seasonal_order=(6,1,1,12))  #pdq
results=model.fit()

# %%
CS['forecast']=results.predict(start=50,end=97,dynamic=True)

# %%
plt.figure(figsize=(15,5),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
l1=sns.lineplot(x='Date',y='Comp Stock',data=CS,label="INVESTMENT",color='orange')
l2=sns.lineplot(x='Date',y='forecast',data=CS,label="PREDICTION",color='blue')
plt.xlabel('DATE\n',weight='bold')
plt.ylabel('INVESTMENT\n',weight='bold')
plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',ncol=2, mode="expand", borderaxespad=0.1)
plt.show()

# %% [markdown]
# **FORECASTING FOR NEXT 4 YEARS THAT IS 2018 TO 2021**

# %%
CS.set_index('Date', inplace=True)

# %%
future_dates=[CS.index[-1]+ DateOffset(months=x)for x in range(0,49)]

# %%
future=pd.DataFrame(index=future_dates[1:],columns=CS.columns)

# %%
future.head(5)
# Out:
#            Comp Stock forecast
# 2018-01-01        NaN      NaN
# 2018-02-01        NaN      NaN
# 2018-03-01        NaN      NaN
# 2018-04-01        NaN      NaN
# 2018-05-01        NaN      NaN

# %%
future.tail(5)
# Out:
#            Comp Stock forecast
# 2021-08-01        NaN      NaN
# 2021-09-01        NaN      NaN
# 2021-10-01        NaN      NaN
# 2021-11-01        NaN      NaN
# 2021-12-01        NaN      NaN

# %%
df=pd.concat([CS,future])
df.reset_index(inplace=True)

# %%
df['forecast'] = results.predict(start = 97, end = 144, dynamic= True)  
df
# Out:
#          index  Comp Stock  forecast
# 0   2009-12-01    0.017354       NaN
# 1   2010-01-01    0.021966       NaN
# 2   2010-02-01    0.080202       NaN
# 3   2010-03-01    0.108993       NaN
# 4   2010-04-01    0.016247       NaN
# ..         ...         ...       ...
# 140 2021-08-01         NaN  0.025997
# 141 2021-09-01         NaN  0.025332
# 142 2021-10-01         NaN  0.021182
# 143 2021-11-01         NaN  0.010729
# 144 2021-12-01         NaN  0.022055
#
# [145 rows x 3 columns]

# %%
plt.figure(figsize=(15,5),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
l1=sns.lineplot(x='index',y='Comp Stock',data=df,label="INVESTMENT",color='crimson')
l2=sns.lineplot(x='index',y='forecast',data=df,label="PREDICTION",color='yellow')
plt.xlabel('DATE\n',weight='bold')
plt.ylabel('INVESTMENT\n',weight='bold')
plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',ncol=2, mode="expand", borderaxespad=0.1)
plt.show()
