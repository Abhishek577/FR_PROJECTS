# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
from pandas.plotting import autocorrelation_plot
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
stock=pd.read_csv(r'C:\Users\ABHISHEK\CSV\Company Stock and Investment.csv')
stock.head(7)
# Out:
#          Date  Oil Investments  Gold Investments  Comp Stock  \
# 0  31-12-2009         0.025417          0.000150    0.017354
# 1  04-01-2010         0.026830          0.001097    0.015565
# 2  05-01-2010         0.002699          0.001560    0.001729
# 3  06-01-2010         0.021688          0.006009   -0.015906
# 4  07-01-2010        -0.006256          0.000221   -0.001849
# 5  08-01-2010         0.001269         -0.013097    0.006648
# 6  11-01-2010        -0.002417          0.023297   -0.008822
#
#    Other sharesInvestments
# 0                 0.006848
# 1                -0.004609
# 2                 0.005900
# 3                -0.018116
# 4                -0.017013
# 5                 0.027077
# 6                -0.024041

# %%
stock.shape
# Out:
# (1984, 5)

# %% [markdown]
# ***`Here we are going to predict the stock and  investment of the company in 'OIL'`***

# %%
oil=stock.drop(['Gold Investments','Comp Stock','Other sharesInvestments'],axis=1)
oil.head(7)
# Out:
#          Date  Oil Investments
# 0  31-12-2009         0.025417
# 1  04-01-2010         0.026830
# 2  05-01-2010         0.002699
# 3  06-01-2010         0.021688
# 4  07-01-2010        -0.006256
# 5  08-01-2010         0.001269
# 6  11-01-2010        -0.002417

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1984 entries, 0 to 1983
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1984 non-null   object
#  1   Oil Investments  1984 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 31.1+ KB

# %% [markdown]
# `converting the date column into datetime  from object type`

# %%
oil['Date']=pd.to_datetime(oil['Date'])
oil.head(12)
#it is in yyyy-mm-dd format so we have all monthly data
# Out:
#          Date  Oil Investments
# 0  2009-12-31         0.025417
# 1  2010-04-01         0.026830
# 2  2010-05-01         0.002699
# 3  2010-06-01         0.021688
# 4  2010-07-01        -0.006256
# 5  2010-08-01         0.001269
# 6  2010-11-01        -0.002417
# 7  2010-12-01        -0.021202
# 8  2010-01-13        -0.013987
# 9  2010-01-14        -0.003892
# 10 2010-01-15        -0.017517
# 11 2010-01-19         0.013084

# %% [markdown]
# `Here we can see that 2010 jan have more than 1 days while we have data of only 1 day in case of 2010-march so they must be brought back to a normal stage`

# %%
oil.tail(12)
# Out:
#            Date  Oil Investments
# 1972 2017-10-31         0.004620
# 1973 2017-01-11        -0.000736
# 1974 2017-02-11         0.004234
# 1975 2017-03-11         0.019798
# 1976 2017-06-11         0.030739
# 1977 2017-07-11        -0.002616
# 1978 2017-08-11        -0.006470
# 1979 2017-09-11         0.005984
# 1980 2017-10-11        -0.007173
# 1981 2017-11-13         0.000352
# 1982 2017-11-14        -0.019376
# 1983 2017-11-15        -0.007006

# %% [markdown]
# ` The same thing can be seen here also 2017 november have investment data for 3 days while2017 jan have investment data of only one day`

# %%
oil.set_index('Date', inplace=True)

# %%
#clubbing the data which will show the oil investment per month as at some index we have data of more than 1 days for a single month
oil=oil.resample('MS').sum()

# %%
oil.reset_index(inplace=True)
oil.head(12)
# Out:
#          Date  Oil Investments
# 0  2009-12-01         0.025417
# 1  2010-01-01        -0.029126
# 2  2010-02-01         0.184326
# 3  2010-03-01         0.095769
# 4  2010-04-01        -0.067218
# 5  2010-05-01        -0.017535
# 6  2010-06-01         0.001670
# 7  2010-07-01         0.002876
# 8  2010-08-01         0.008176
# 9  2010-09-01         0.109590
# 10 2010-10-01         0.072053
# 11 2010-11-01        -0.059708

# %%
oil.describe()
# Out:
#        Oil Investments
# count        97.000000
# mean         -0.008899
# std           0.125303
# min          -0.953182
# 25%          -0.037497
# 50%          -0.000692
# 75%           0.045461
# max           0.248424

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             97 non-null     datetime64[ns]
#  1   Oil Investments  97 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.6 KB

# %% [markdown]
# `visualizing the investment column`

# %%
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
plt.figure(figsize=(15,5),dpi=120)
sns.lineplot(x='Date',y='Oil Investments',data=oil,dashes=True,markers='2',estimator=None,ci=55,err_style='band',color='darkorange')
plt.show()

# %%
def adf(data):
    result=adfuller(data)
    labels = ['ADF Test Statistic','p-value','Lags Used','Number of Observations']
    for i in range(len(labels)):
        print(labels[i],' = ', result[i])
    if result[1]>0.05:
        print('The',labels[1],' is higher than 0.05 and it strongly support Null hypothesis that the data is non stationary')
    else:
         print('\nThe',labels[1],' is less than 0.05 and it strongly rejects Null hypothesis and hold the alternate hypothesis which says that the data is stationary')

# %%
adf(oil['Oil Investments'])
# Out:
# ADF Test Statistic  =  -7.1269027022747835
# p-value  =  3.6005710703274825e-10
# Lags Used  =  2
# Number of Observations  =  94
#
# The p-value  is less than 0.05 and it strongly rejects Null hypothesis and hold the alternate hypothesis which says that the data is stationary

# %% [markdown]
# ***`So from the graph and ADF test it's clear that the p value is higher than 0.05 which lead to drooping null hypothesis`***

# %%
plt.figure(figsize=(15,5),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
autocorrelation_plot(oil['Oil Investments'])
plt.show()

# %%
fig=plt.figure(figsize=(20,10),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(oil['Oil Investments'],lags=20,ax=ax1)   #to determine AR value
ax2 = fig.add_subplot(212)

fig = sm.graphics.tsa.plot_pacf(oil['Oil Investments'],lags=20,ax=ax2) # to determine MA value
plt.tight_layout
plt.show()

# %%
model=sm.tsa.statespace.SARIMAX(oil['Oil Investments'],order=(5,1,8),seasonal_order=(5,1,8,12))
results=model.fit()

# %%
oil['forecast']=results.predict(start=50,end=97,dynamic=True)

# %%
oil
# Out:
#          Date  Oil Investments  forecast
# 0  2009-12-01         0.025417       NaN
# 1  2010-01-01        -0.029126       NaN
# 2  2010-02-01         0.184326       NaN
# 3  2010-03-01         0.095769       NaN
# 4  2010-04-01        -0.067218       NaN
# ..        ...              ...       ...
# 92 2017-08-01        -0.124324 -0.033773
# 93 2017-09-01         0.034083 -0.023127
# 94 2017-10-01         0.101426  0.014793
# 95 2017-11-01         0.058930 -0.038906
# 96 2017-12-01         0.016362  0.013653
#
# [97 rows x 3 columns]

# %%
plt.figure(figsize=(15,5),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
l1=sns.lineplot(x='Date',y='Oil Investments',data=oil,label="INVESTMENT",color='orange')
l2=sns.lineplot(x='Date',y='forecast',data=oil,label="PREDICTION",color='blue')
plt.xlabel('DATE\n',weight='bold')
plt.ylabel('INVESTMENT\n',weight='bold')
plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',ncol=2, mode="expand", borderaxespad=0.1)
plt.show()

# %% [markdown]
# **FORECASTING FOR NEXT 4 YEARS THAT IS 2018 TO 2021**

# %%
oil.set_index('Date', inplace=True)

# %%
future_dates=[oil.index[-1]+ DateOffset(months=x)for x in range(0,49)]

# %%
future=pd.DataFrame(index=future_dates[1:],columns=oil.columns)

# %%
future.head(5)
# Out:
#            Oil Investments forecast
# 2018-01-01             NaN      NaN
# 2018-02-01             NaN      NaN
# 2018-03-01             NaN      NaN
# 2018-04-01             NaN      NaN
# 2018-05-01             NaN      NaN

# %%
future.tail(5)
# Out:
#            Oil Investments forecast
# 2021-08-01             NaN      NaN
# 2021-09-01             NaN      NaN
# 2021-10-01             NaN      NaN
# 2021-11-01             NaN      NaN
# 2021-12-01             NaN      NaN

# %%
df=pd.concat([oil,future])
df.reset_index(inplace=True)

# %%
df['forecast'] = results.predict(start = 97, end = 144, dynamic= True)  
df
# Out:
#          index  Oil Investments  forecast
# 0   2009-12-01         0.025417       NaN
# 1   2010-01-01        -0.029126       NaN
# 2   2010-02-01         0.184326       NaN
# 3   2010-03-01         0.095769       NaN
# 4   2010-04-01        -0.067218       NaN
# ..         ...              ...       ...
# 140 2021-08-01              NaN -0.046623
# 141 2021-09-01              NaN -0.054978
# 142 2021-10-01              NaN -0.006677
# 143 2021-11-01              NaN -0.066090
# 144 2021-12-01              NaN -0.011198
#
# [145 rows x 3 columns]

# %%
plt.figure(figsize=(15,5),dpi=120)
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
l1=sns.lineplot(x='index',y='Oil Investments',data=df,label="INVESTMENT",color='red')
l2=sns.lineplot(x='index',y='forecast',data=df,label="PREDICTION",color='yellow')
plt.xlabel('DATE\n',weight='bold')
plt.ylabel('INVESTMENT\n',weight='bold')
plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',ncol=2, mode="expand", borderaxespad=0.1)
plt.show()
